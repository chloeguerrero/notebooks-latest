# %%
__nbid__ = '0002'
__author__ = 'Knut Olsen <knut.olsen@noirlab.edu>, Robert Nikutta <robert.nikutta@noirlab.edu>'
__version__ = '20240603' # yyyymmdd
__datasets__ = ['smash_dr1', 'des_dr1']
__keywords__ = ['tutorial', 'query', 'image cutout', 'globular cluster', 'SIA']

# %% [markdown]
# # Welcome to Astro Data Lab
# *Knut Olsen, Robert Nikutta, Astro Data Lab Team*

# %% [markdown]
# ## Table of contents
# * [Goals](#goals)
# * [Summary](#summary)
# * [Disclaimer & attribution](#attribution)
# * [Imports & setup](#import)
# * [Authentication](#auth)
# * [Basic info about database tables](#basic)
# * [A simple database query](#query)
# * [An image cutout](#image)
# * [Resources and references](#resources)

# %% [markdown]
# <a class="anchor" id="goals"></a>
# # Goals
# Learn how to:
# * Import standard Data Lab modules
# * Set up the Simple Image Access (SIA) Service to let you create image cutouts
# * Discover the datasets available in the database
# * Issue a simple query to the database
# * Retrieve image cutouts
# * Create a color image

# %% [markdown]
# <a class="anchor" id="summary"></a>
# # Summary
#
# If you've gotten this far, you're planning to use the Data Lab Jupyter notebook environment to access, explore, and analyze datasets available in the Data Lab.  This notebook aims to provide you with a very quick overview of how to use some common Data Lab services.  For more detailed explanations of data access, the full range of services, or for complete science examples, check out the other notebooks in this directory tree.

# %% [markdown]
# <a class="anchor" id="attribution"></a>
# # Disclaimer & attribution
#
# Disclaimers
# -----------
# Note that using the Astro Data Lab constitutes your agreement with our minimal [Disclaimers](https://datalab.noirlab.edu/disclaimers.php).
#
# Acknowledgments
# ---------------
# If you use **Astro Data Lab** in your published research, please include the text in your paper's Acknowledgments section:
#
# _This research uses services or data provided by the Astro Data Lab, which is part of the Community Science and Data Center (CSDC) Program of NSF NOIRLab. NOIRLab is operated by the Association of Universities for Research in Astronomy (AURA), Inc. under a cooperative agreement with the U.S. National Science Foundation._
#
# If you use **SPARCL jointly with the Astro Data Lab platform** (via JupyterLab, command-line, or web interface) in your published research, please include this text below in your paper's Acknowledgments section:
#
# _This research uses services or data provided by the SPectra Analysis and Retrievable Catalog Lab (SPARCL) and the Astro Data Lab, which are both part of the Community Science and Data Center (CSDC) Program of NSF NOIRLab. NOIRLab is operated by the Association of Universities for Research in Astronomy (AURA), Inc. under a cooperative agreement with the U.S. National Science Foundation._
#
# In either case **please cite the following papers**:
#
# * Data Lab concept paper: Fitzpatrick et al., "The NOAO Data Laboratory: a conceptual overview", SPIE, 9149, 2014, https://doi.org/10.1117/12.2057445
#
# * Astro Data Lab overview: Nikutta et al., "Data Lab - A Community Science Platform", Astronomy and Computing, 33, 2020, https://doi.org/10.1016/j.ascom.2020.100411
#
# If you are referring to the Data Lab JupyterLab / Jupyter Notebooks, cite:
#
# * Juneau et al., "Jupyter-Enabled Astrophysical Analysis Using Data-Proximate Computing Platforms", CiSE, 23, 15, 2021, https://doi.org/10.1109/MCSE.2021.3057097
#
# If publishing in a AAS journal, also add the keyword: `\facility{Astro Data Lab}`
#
# And if you are using SPARCL, please also add `\software{SPARCL}` and cite:
#
# * Juneau et al., "SPARCL: SPectra Analysis and Retrievable Catalog Lab", Conference Proceedings for ADASS XXXIII, 2024
# https://doi.org/10.48550/arXiv.2401.05576
#
# The NOIRLab Library maintains [lists of proper acknowledgments](https://noirlab.edu/science/about/scientific-acknowledgments) to use when publishing papers using the Lab's facilities, data, or services.

# %% [markdown]
# <a class="anchor" id="import"></a>
# # Imports and setup
# To use the Astro Data Lab, you'll generally want to import common packages such as NumPy and matplotlib.  From the datalab package, you'll at minimum need the authClient module to get an authorization token (even if using Data Lab anonymously) and the queryClient module to issue a query against the catalog database.
#
# For storing results in virtual storage and myDB, you'll need the storeClient module *and* log in as an authenticated user.
#
# The helpers module has many convience functions.  See the <a href="http://datalab.noirlab.edu/docs/manual/UsingAstroDataLab/ClientInterfaces/Helpers/Helpers.html">online documentation</a> for a summary.
#
# Use of the image cutout service (SIA) requires the external PyVO package, and the URL of the SIA service that you will use.  Data Lab has a general SIA service containing all available images from [Astro Data Archive](https://astroarchive.noirlab.edu/), as well as a number of survey-specific services.  See the [SIA service HowTo notebook](https://github.com/astro-datalab/notebooks-latest/blob/master/04_HowTos/SiaService/How_to_use_the_Simple_Image_Access_service.ipynb) for examples.

# %%
# std library imports
from getpass import getpass

# 3rd party
import numpy as np
import pylab as plt
import matplotlib
from astropy import utils, io
from astropy.visualization import make_lupton_rgb
# %matplotlib inline

# Data Lab and related imports

# You'll need at least these for authenticating and for issuing database queries
from dl import authClient as ac, queryClient as qc

# Get helpers for various convenience function
from dl.helpers.utils import convert

# You'll want storeClient if you plan to use virtual storage or myDB
# from dl import storeClient as sc

# To get image cutouts, you'll need the VO-based SIA package, and define which SIA service to use
from pyvo.dal import sia
DEF_ACCESS_URL = "https://datalab.noirlab.edu/sia/des_dr1" # DES SIA service URL
svc = sia.SIAService(DEF_ACCESS_URL)

# %% [markdown]
# <a class="anchor" id="auth"></a>
# # Authentication
# For the purposes of this notebook, there is no need to log in with your username and password inside the notebook. As an anonymous user, you can issue queries to the database or retrieve image cutouts, but not store your results in virtual storage or myDB. If you need these things, you would use the authClient module to log in. You only need to do this once (unless you log out through authClient), as the authentication token is stored on the server and automatically detected.
#
# If you need to log in to Data Lab, un-comment the cell below and execute it:

# %%
#token = ac.login(input("Enter user name: (+ENTER) "),getpass("Enter password: (+ENTER) "))
ac.whoAmI()
# Out:
# 'anonymous'

# %% [markdown]
# <a class="anchor" id="basic"></a>
# # Basic info about database tables
#
# ### What datasets are available?
# The queryClient has a `schema` method to give you information about available databases, tables, and columns.  If we call `qc.schema()` with an empty first argument, we'll get information on the available datasets and a one-line description for most of them.

# %%
print(qc.schema())
# Out:
#      Schema Name   Description
#      -----------   -----------
#          allwise   The AllWISE data release
#      buzzard_dr1   Buzzard Data Release 1
#      catwise2020   CatWise 2020 data, containing the main catalog with 191 co
#                    lumns and 1.89 billion rows
#          dad_dr1   DECam Asteroid Database -- Data Release 1
#          dad_dr2   DECam Asteroid Database -- Data Release 2
#       decaps_dr1   DECaPS Survey Data Release 1
#       decaps_dr2   DECaPS Survey Data Release 2
#        delve_dr1   First data release of the DELVE survey (Drlica-Wagner et a
#                    l. 2020)
#        delve_dr2   Second data release of the DELVE survey
#          des_dr1   Dark Energy Survey (DES) Data Release 1
#          des_dr2   Dark Energy Survey (DES) Data Release 2
#         des_sva1   DES SVA1 Data Products
#         desi_edr   Early Data Release from the Dark Energy Spectroscopic Inst
#                    rument
#           dltest
#         gaia_dr1   GAIA Data Release 1
#         gaia_dr2   Gaia Data Release 2 -- April 25, 2018
#         gaia_dr3   Gaia Data Release 3
#        gaia_edr3   The early installment of the third Gaia data release, Gaia
#                    EDR3, encompasses astrometry and photometry, complemented
#                    with radial velocities copied from Gaia DR2 after removal
#                    of a small number of spurious entries.
#        gnirs_dqs   Gemini North Near-Infrared Distant Quasar Survey
#      gogreen_dr1   GOGREEN and GCLASS first data release survey catalogues
#        hipparcos   ftp://cdsarc.u-strasbg.fr/pub/cats/I/239/ReadMe
#       hipparcos2   A new reduction of the astrometric data as produced by the
#                    Hipparcos mission has been published, claiming accuracies
#                    for nearly all stars brighter than magnitude Hp=8 to be b
#                    etter, by up to a factor 4, than in the original catalogue
#                    . ftp://cdsarc.u-strasbg.fr/pub/cats/I/311/ReadMe
#  ivoa_calibrated   Instrument calibrated images for specific surveys
#       ivoa_coadd   Subset of stacked calibrated images for specific surveys
#  ivoa_decaps_dr1   IVOA SIA/ObsCore Tables for ivoa_decaps_dr1 images
#  ivoa_decaps_dr2   IVOA SIA/ObsCore Tables for ivoa_decaps_dr2 images
# ivoa_demcels_dr1   IVOA SIA/ObsCore Tables for ivoa_demcels_dr1 images
#     ivoa_des_dr1   IVOA SIA/ObsCore Tables for Dark Energy Survey DR1 images
#     ivoa_des_dr2   IVOA SIA/ObsCore Tables for ivoa_des_dr2 images
#  ivoa_des_dr2_se   IVOA SIA/ObsCore Tables for ivoa_des_dr2_se images
#    ivoa_des_sva1   IVOA SIA/ObsCore Tables for ivoa_des_sva1 images
#      ivoa_des_y1   IVOA SIA/ObsCore Tables for ivoa_des_y1 images
#      ivoa_des_y2   IVOA SIA/ObsCore Tables for ivoa_des_y2 images
#      ivoa_des_y3   IVOA SIA/ObsCore Tables for ivoa_des_y3 images
#      ivoa_des_y4   IVOA SIA/ObsCore Tables for ivoa_des_y4 images
# ivoa_gogreen_dr1   IVOA SIA/ObsCore Tables for gogreen_dr1 images
#      ivoa_ls_dr8   IVOA SIA/ObsCore Tables for ls_dr8 images
#      ivoa_ls_dr9   IVOA SIA/ObsCore Tables for ls_dr9 images
#         ivoa_nsa   IVOA SIA/ObsCore Tables for NOAO Science Archive images
#     ivoa_nsc_dr2   IVOA SIA/ObsCore Tables for ivoa_nsc_dr2 images
#         ivoa_raw   Subset of raw uncalibrated images for specific surveys
#    ivoa_sdss_dr9   IVOA SIA/ObsCore Tables for sdss_dr9 images
#   ivoa_smash_dr1   IVOA SIA/ObsCore Tables for SMASH DR1 images
#   ivoa_smash_dr2   IVOA SIA/ObsCore Tables for ivoa_smash_dr2 images
#   ivoa_splus_dr1   IVOA SIA/ObsCore Tables for ivoa_splus_dr1 images
#   ivoa_splus_edr   IVOA SIA/ObsCore Tables for ivoa_splus_edr images
#    ivoa_stripe82   The subset of images that overlap with SDSS Stripe 82
#          ls_dr10   Legacy Survey (LS) Data Release 10
#           ls_dr8   Legacy Survey Data Release 8
#           ls_dr9   Legacy Survey (LS) Data Release 9
#         ls_dr9sv
#         lsst_sim   lsst_sim
#             mydb   MyDB table schema
#           nbdata   Group of datasets intended to use mostly in DataLab notebooks
#          nsc_dr1   NOIRLab Source Catalog Data Release 1
#          nsc_dr2   NOIRLab Source Catalog Data Release 2
#         pgir_dr1   Palomar Gattini-IR Data Release 1 of near-IR, J-band photo
#                    metry that covers the first ~4 years of the survey operati
#                    on with a cadence of a few days and sensitivity of around
#                    J ~ 15.
#          phat_v2   Panchromatic Hubble Andromeda Treasury Version 2
#          phat_v3   Panchromatic Hubble Andromeda Treasury Version 3
#        sdss_dr12   Sloan Digital Sky Survey Data Release 12
#        sdss_dr13   Sloan Digital Sky Survey Data Relase 13
#        sdss_dr16   Sloan Digital Sky Survey Data Release 16
#        sdss_dr17   Sloan Digital Sky Survey Data Release 17
#          sga2020   Siena Galaxy Atlas 2020
#    skymapper_dr4   The fourth data release of the SkyMapper Southern Survey;
#                    6-band optical survey conducted with the Australian Nation
#                    al Universitys 1.3m SkyMapper Telescope at Siding Spring O
#                    bservatory in Australia
#        smash_dr1   SMASH Data Release 1
#        smash_dr2   SMASH Data Release 2
#           sparcl   SPectra Analysis & Retrieveable Catalog Lab
#        splus_dr1   The Southern Photometric Local Universe Survey (S-PLUS) --
#                    Data Release 1
#        splus_dr2   The Southern Photometric Local Universe Survey (S-PLUS) --
#                    Data Release 2
#        splus_dr4   The Southern Photometric Local Universe Survey (S-PLUS) --
#                    Data Release 4
#        splus_edr   The Southern Photometric Local Universe Survey (S-PLUS) --
#                    Data Release 1
#         stripe82   Primary object catalogs in Stripe 82 footprint
#       tap_schema   TAP Schema Tables
#          twomass   2MASS All-Sky Catalogs (2003)
#           tycho2   The Tycho-2 Catalogue is an astrometric reference catalogu
#                    e containing positions, proper motions and two-colour phot
#                    ometry for the 2.5 million brightest stars in the sky. The
#                    catalogue is based on observations made using the Hipparc
#                    os satellite star mapper and is constructed using the same
#                    observations that were used to create the original Tycho
#                    catalogue. Improved reduction techniques have resulted in
#                    a catalogue with significantly more entries and in improve
#                    d precision.
#  ukidss_dr11plus   Five different UKIDSS databases contain calibrated data fr
#                    om the UKIRT Wide Field Camera (WFCAM).
#       unwise_dr1   unWISE DR1 band-merged catalog
#             usno   USNO Astrometry Catalogs
#          vhs_dr5   VISTA Hemisphere Survey (VHS) band-merged multi-waveband c
#                    atalogues Data Release 5

# %% [markdown]
# ### Get list of tables
# If we call `qc.schema()` with a specific dataset name, we'll see what tables are available for that dataset.  Here's what's available for SMASH DR1:

# %%
print(qc.schema('desi_edr'))
# Out:
# Schema: desi_edr
#
#       Table Name   Description
#       ----------   -----------
#         exposure   Summary quantities for every DESI exposure
#      fiberassign   Quantities obtained when a DESI target is assigned to a fiber
#            frame   Summary quantities for each petal of the DESI instrument i
#                    n a given exposure; in normal operation there are ten fram
#                    es for every exposure
#       photometry   Photometric quantities from LS DR9 for every TARGETID
#        potential   For a given tile, this table lists all targets that could
#                    have received a fiber assignment
#           target   The quantities obtained when photometric objects are analy
#                    zed in the target selection process
#             tile   Summary quantities for every DESI tile (pointing on the sky)
# x1p5__zpix__allwise__source   desi_edr.zpix and xmatch_std.allwise__source crossmatch (1
#                    .5 arcsec)
# x1p5__zpix__gaia_dr3__gaia_source   desi_edr.zpix and xmatch_std.gaia_dr3__gaia_source crossma
#                    tch (1.5 arcsec)
# x1p5__zpix__nsc_dr2__object   desi_edr.zpix and xmatch_std.nsc_dr2__object crossmatch (1
#                    .5 arcsec)
# x1p5__zpix__sdss_dr17__specobj   desi_edr.zpix and xmatch_std.sdss_dr17__specobj crossmatch
#                    (1.5 arcsec)
# x1p5__zpix__unwise_dr1__object   desi_edr.zpix and xmatch_std.unwise_dr1__object crossmatch
#                    (1.5 arcsec)
#             zpix   Redshift and other quantities for spectra that have been g
#                    rouped and coadded by HEALPixel
#            ztile   Redshift and other quantities for spectra that have been g
#                    rouped and coadded by tile

# %%
# Get the schema for 'desi_edr'
schema_info = qc.schema('desi_edr')

# Extract table names from the output (assuming each table name is at the start of each line)
tables = [line.strip().split()[0] for line in schema_info.split("\n")[3:] if line.strip()]

for table in tables:
    print(f"\nSchema for table: {table}")
    print("-" * 50)
    
    table_info = qc.schema(f'desi_edr.{table}')
    
    # Print the schema details
    print(table_info)
    print("\n" + "=" * 50)


#print(qc.schema('desi_edr.exposure'))
#print(qc.schema('desi_edr.fiberassign'))
#print(qc.schema('desi_edr.ztile'))
#print(qc.schema('desi_edr.ztile.spectype'))
# Out:
# Schema for table: Table
# --------------------------------------------------
#
# Schema: desi_edr
#  Table: Table
#
#      Column Name   Description
#      -----------   -----------
#
#
# ==================================================
#
# Schema for table: ----------
# --------------------------------------------------
#
# Schema: desi_edr
#  Table: ----------
#
#      Column Name   Description
#      -----------   -----------
#
#
# ==================================================
#
# Schema for table: exposure
# --------------------------------------------------
#
# Schema: desi_edr
#  Table: exposure
#
#      Column Name   Description
#      -----------   -----------
# fiberfac_bgs_gfa   Same as FIBERFAC_GFA except for a BGS profile
#              mjd   Modified Julian Date when shutter was opened for this exposure
#          exptime   Length of time shutter was open
#     efftime_spec   Effective exposure time for nominal conditions derived fro
#                    m the TSNR2 fits to the spectroscopy
#              ebv   Galactic extinction E(B-V) reddening from SFD98
#       seeing_etc   Average FWHM atmospheric seeing during this exposure as me
#                    asured by ETC
#        tsnr2_lya   LYA template (S/N)^2 summed over B, R, Z
# lya_efftime_dark   Effective exposure time for nominal dark conditions inferr
#                    ed for LYA targets
# transparency_gfa   Average airmass during this exposure as measured by GFA
#       seeing_gfa   Average FWHM atmospheric seeing during this exposure as me
#                    asured by GFA
# fiber_fracflux_gfa   Fraction of the flux entering the fiber relative to nomina
#                    l 1.1 arcsec seeing using the PSF inferred from the GFAs
# fiber_fracflux_elg_gfa   Fraction of the flux entering the fiber relative to nomina
#                    l 1.1 arcsec seeing using the PSF inferred from the GFAs f
#                    or a source with an ELG profile (0.45 arcsec exponential g
#                    alaxy profile)
# fiber_fracflux_bgs_gfa   Fraction of the flux entering the fiber relative to nomina
#                    l 1.1 arcsec seeing using the PSF inferred from the GFAs f
#                    or a source with a BGS profile (deV profile half light rad
#                    ius of 1.5 arcsec)
#     fiberfac_gfa   Fraction of light entering a fiber relative to expectation
#                    s for 1.1 arcsec seeing, transparency 1, for an object wit
#                    h a PSF profile, measured by comparing the flux integrated
#                    over a 107 micron diameter circle on the GFA images cente
#                    red at the PlateMaker expectations for where stars should
#                    land
# fiberfac_elg_gfa   Same as FIBERFAC_GFA except for an ELG profile
#      airmass_gfa   Average airmass during this exposure as measured by GFA
#   sky_mag_ab_gfa   Sky background in the GFA passband, measured from the GFA
#                    backgrounds
#   sky_mag_g_spec   Sky background measured in the spectroscopy integrated ove
#                    r the DECam g passband, AB mags
#   sky_mag_r_spec   Sky background measured in the spectroscopy integrated ove
#                    r the DECam r passband, AB mags
#   sky_mag_z_spec   Sky background measured in the spectroscopy integrated ove
#                    r the DECam z passband, AB mags
#      efftime_gfa   Effective exposure time for nominal conditions derived fro
#                    m exposure GFA data
# efftime_dark_gfa   Effective exposure time for nominal dark conditions inferr
#                    ed from GFA data
# efftime_bright_gfa   Effective exposure time for nominal bright conditions infe
#                    rred from GFA data
# efftime_backup_gfa   Effective exposure time for nominal backup conditions infe
#                    rred from GFA data
#           tilera   RA of tile given in fiberassign file
#          tiledec   DEC of tile given in fiberassign file
#         mintfrac   Minimum fraction of GOALTIME acceptable for considering a
#                    tile complete
#          airmass   Average airmass during this exposure
#      efftime_etc   Effective exposure time for nominal conditions inferred fr
#                    om ETC data
#        tsnr2_elg   ELG template (S/N)^2 summed over B, R, Z
#        tsnr2_qso   QSO template (S/N)^2 summed over B, R, Z
#        tsnr2_lrg   LRG template (S/N)^2 summed over B, R, Z
#        tsnr2_bgs   BGS template (S/N)^2 summed over B, R, Z
#    tsnr2_gpbdark   GPBDARK template (S/N)^2 summed over B, R, Z
#  tsnr2_gpbbright   GPBBRIGHT template (S/N)^2 summed over B, R, Z
#  tsnr2_gpbbackup   GPBBACKUP template (S/N)^2 summed over B, R, Z
# lrg_efftime_dark   Effective exposure time for nominal dark conditions inferr
#                    ed for LRG targets
# elg_efftime_dark   Effective exposure time for nominal dark conditions inferr
#                    ed for ELG targets
# bgs_efftime_bright   Effective exposure time for nominal bright conditions infe
#                    rred for BGS targets
# gpb_efftime_dark   Effective exposure time for nominal dark conditions inferr
#                    ed for GPB targets
# gpb_efftime_bright   Effective exposure time for nominal bright conditions infe
#                    rred for GPB targets
# gpb_efftime_backup   Effective exposure time for nominal backup conditions infe
#                    rred for GPB targets
#        random_id   Random ID in the range 0.0 => 100.0 (not unique)
#            night   Observing night
#            expid   DESI Exposure ID number
#           tileid   Unique DESI tile ID
#         goaltime   Goal for total effective exposure time for the tile
#         date_obs   [UTC] Observation data and start time
#          faprgrm   Fiberassign program name
#         faflavor   Fiberassign flavor name
#          program   DESI program type - BRIGHT, DARK, or BACKUP
#         goaltype   The intended observing conditions for the tile
#           survey   Survey name
#
#
# ==================================================
#
# Schema for table: fiberassign
# --------------------------------------------------
#
# Schema: desi_edr
#  Table: fiberassign
#
#      Column Name   Description
#      -----------   -----------
#        target_ra   Target right ascension
#       target_dec   Target declination
#             elon   Ecliptic longitude
#             elat   Ecliptic latitude
#             glon   Galactic longitude
#             glat   Galactic latitude
#               id   Arbitrary primary key composed from targetid, tileid, location
#         targetid   Unique DESI target ID
#        fa_target   Targeting bit internally used by fiberassign (linked with
#                    FA_TYPE)
#       lambda_ref   Wavelength at which targets should be centered on fibers
#    fiberassign_x   Expected CS5 X on focal plane
#    fiberassign_y   Expected CS5 Y on focal plane
#        random_id   Random ID in the range 0.0 => 100.0 (not unique)
#             htm9   Ninth level (~10 arcmin resolution) Hierarchical Triangula
#                    r Mesh index (Szalay et al. 2007)
#          ring256   Ring-scheme HEALPix (Gorski et al. 2005) index with Nsides
#                    =256 (~14 arcmin size)
#         nest4096   Nested-scheme HEALPix (Gorski et al. 2005) index with Nsid
#                    es=4096 (~52 arcsec size)
#           tileid   Unique DESI tile ID
#       device_loc   Device location on focal plane [0-523]
#         location   Location on the focal plane PETAL_LOC*1000 + DEVICE_LOC
#            fiber   Fiber ID on the CCDs [0-4999]
#      fiberstatus   Fiber status mask. 0=good
#         priority   Target current priority
#        petal_loc   Petal location [0-9]
#          fa_type   Target type (science, standard, sky, safe, suppsky)
#
#
# ==================================================
#
# Schema for table: frame
# --------------------------------------------------
#
# Schema: desi_edr
#  Table: frame
#
#      Column Name   Description
#      -----------   -----------
#           tileid   Unique DESI tile ID
#              mjd   Modified Julian Date when shutter was opened for this exposure
#        tsnr2_lya   LYA template (S/N)^2 summed over B, R, Z
#          exptime   Length of time shutter was open
#              ebv   Galactic extinction E(B-V) reddening from SFD98
#    tsnr2_gpbdark   GPBDARK template (S/N)^2 summed over B, R, Z
#        tsnr2_elg   ELG template (S/N)^2 summed over B, R, Z
#  tsnr2_gpbbright   GPBBRIGHT template (S/N)^2 summed over B, R, Z
#        tsnr2_bgs   BGS template (S/N)^2 summed over B, R, Z
#  tsnr2_gpbbackup   GPBBACKUP template (S/N)^2 summed over B, R, Z
#        tsnr2_qso   QSO template (S/N)^2 summed over B, R, Z
#        tsnr2_lrg   LRG template (S/N)^2 summed over B, R, Z
#        random_id   Random ID in the range 0.0 => 100.0 (not unique)
#          frameid   Arbitrary primary key composed from expid, camera
#            night   Observing night
#            expid   DESI Exposure ID number
#           camera   Camera identifier. Passband and SPECGRPH ([brz][0-9])
#
#
# ==================================================
#
# Schema for table: n
# --------------------------------------------------
#
# Schema: desi_edr
#  Table: n
#
#      Column Name   Description
#      -----------   -----------
#
#
# ==================================================
#
# Schema for table: es
# --------------------------------------------------
#
# Schema: desi_edr
#  Table: es
#
#      Column Name   Description
#      -----------   -----------
#
#
# ==================================================
#
# Schema for table: photometry
# --------------------------------------------------
#
# Schema: desi_edr
#  Table: photometry
#
#      Column Name   Description
#      -----------   -----------
#               ra   Right ascension
#              dec   Declination
#             elon   Ecliptic longitude
#             elat   Ecliptic latitude
#             glon   Galactic longitude
#             glat   Galactic latitude
#            ls_id   Unique Legacy Survey object ID
#           ref_id   Tyc1*1000000+Tyc2*10+Tyc3 for Tycho-2; sourceid for Gaia DR2
#         targetid   Unique DESI target ID
#          ra_ivar   Right ascension inverse variance
#         dec_ivar   Declination inverse variance
#       dchisq_psf   Difference in chi-squared between PSF (stellar) Tractor mo
#                    del fits
#       dchisq_rex   Difference in chi-squared between REX (round exponential g
#                    alaxy) Tractor model fits
#       dchisq_dev   Difference in chi-squared between DEV (deVauc) Tractor mod
#                    el fits
#       dchisq_exp   Difference in chi-squared between EXP (exponential) Tracto
#                    r model fits
#       dchisq_ser   Difference in chi-squared between SER (Sersic) Tractor mod
#                    el fits
#              ebv   Galactic extinction E(B-V) reddening from SFD98
#           flux_g   Flux in the Legacy Survey g-band (AB)
#           flux_r   Flux in the Legacy Survey r-band (AB)
#           flux_z   Flux in the Legacy Survey z-band (AB)
#      flux_ivar_g   Inverse variance of FLUX_G (AB)
#      flux_ivar_r   Inverse variance of FLUX_R (AB)
#      flux_ivar_z   Inverse variance of FLUX_Z (AB)
# mw_transmission_g   Milky Way dust transmission in LS g-band
# mw_transmission_r   Milky Way dust transmission in LS r-band
# mw_transmission_z   Milky Way dust transmission in LS z-band
#       fracflux_g   Profile-weighted fraction of the flux from other sources d
#                    ivided by the total flux in g (typically [0,1])
#       fracflux_r   Profile-weighted fraction of the flux from other sources d
#                    ivided by the total flux in r (typically [0,1])
#       fracflux_z   Profile-weighted fraction of the flux from other sources d
#                    ivided by the total flux in z (typically [0,1])
#     fracmasked_g   Profile-weighted fraction of pixels masked from all observ
#                    ations of this object in g, strictly between [0,1]
#     fracmasked_r   Profile-weighted fraction of pixels masked from all observ
#                    ations of this object in r, strictly between [0,1]
#     fracmasked_z   Profile-weighted fraction of pixels masked from all observ
#                    ations of this object in z, strictly between [0,1]
#         fracin_g   Fraction of a sources flux within the blob in g, near unit
#                    y for real sources
#         fracin_r   Fraction of a sources flux within the blob in r, near unit
#                    y for real sources
#         fracin_z   Fraction of a sources flux within the blob in z, near unit
#                    y for real sources
#       psfdepth_g   PSF-based depth in g-band
#       psfdepth_r   PSF-based depth in r-band
#       psfdepth_z   PSF-based depth in z-band
#       galdepth_g   Galaxy model-based depth in Legacy Survey g-band
#       galdepth_r   Galaxy model-based depth in Legacy Survey r-band
#       galdepth_z   Galaxy model-based depth in Legacy Survey z-band
#          flux_w1   WISE flux in W1 (AB)
#          flux_w2   WISE flux in W2 (AB)
#          flux_w3   WISE flux in W3 (AB)
#          flux_w4   WISE flux in W4 (AB)
#     flux_ivar_w1   Inverse variance of FLUX_W1 (AB)
#     flux_ivar_w2   Inverse variance of FLUX_W2 (AB)
#     flux_ivar_w3   Inverse variance of FLUX_W3 (AB)
#     flux_ivar_w4   Inverse variance of FLUX_W4 (AB)
# mw_transmission_w1   Milky Way dust transmission in WISE W1
# mw_transmission_w2   Milky Way dust transmission in WISE W2
# mw_transmission_w3   Milky Way dust transmission in WISE W3
# mw_transmission_w4   Milky Way dust transmission in WISE W4
#      fiberflux_g   Predicted g-band flux within a fiber of diameter 1.5 arcse
#                    c from this object in 1 arcsec Gaussian seeing
#      fiberflux_r   Predicted r-band flux within a fiber of diameter 1.5 arcse
#                    c from this object in 1 arcsec Gaussian seeing
#      fiberflux_z   Predicted z-band flux within a fiber of diameter 1.5 arcse
#                    c from this object in 1 arcsec Gaussian seeing
#   fibertotflux_g   Predicted g-band flux within a fiber of diameter 1.5 arcse
#                    c from all sources at this location in 1 arcsec Gaussian s
#                    eeing
#   fibertotflux_r   Predicted r-band flux within a fiber of diameter 1.5 arcse
#                    c from all sources at this location in 1 arcsec Gaussian s
#                    eeing
#   fibertotflux_z   Predicted z-band flux within a fiber of diameter 1.5 arcse
#                    c from all sources at this location in 1 arcsec Gaussian s
#                    eeing
#        ref_epoch   Reference epoch for Gaia/Tycho astrometry. Typically 2015.
#                    5 for Gaia
#          shape_r   Half-light radius of galaxy model (>0)
#         shape_e1   Ellipticity component 1 of galaxy model for galaxy type MO
#                    RPHTYPE
#         shape_e2   Ellipticity component 2 of galaxy model for galaxy type MO
#                    RPHTYPE
#     shape_r_ivar   Inverse variance of SHAPE_R
#    shape_e1_ivar   Inverse variance of SHAPE_E1
#    shape_e2_ivar   Inverse variance of SHAPE_E2
#           sersic   Power-law index for the Sersic profile model (MORPHTYPE=SER)
#      sersic_ivar   Inverse variance of SERSIC
# gaia_phot_g_mean_mag   Gaia G band magnitude
# gaia_phot_g_mean_flux_over_error   Gaia G band signal-to-noise
# gaia_phot_bp_mean_mag   Gaia BP band magnitude
# gaia_phot_bp_mean_flux_over_error   Gaia BP band signal-to-noise
# gaia_phot_rp_mean_mag   Gaia RP band magnitude
# gaia_phot_rp_mean_flux_over_error   Gaia RP band signal-to-noise
# gaia_phot_bp_rp_excess_factor   Gaia BP/RP excess factor
# gaia_astrometric_sigma5d_max   Gaia longest semi-major axis of the 5-d error ellipsoid
#         parallax   Reference catalog parallax
#    parallax_ivar   Inverse variance of PARALLAX
#             pmra   Reference catalog proper motion in the RA direction
#        pmra_ivar   Inverse variance of PMRA
#            pmdec   Reference catalog proper motion in the Dec direction
#       pmdec_ivar   Inverse variance of PMDEC
#        random_id   Random ID in the range 0.0 => 100.0 (not unique)
#          brickid   Brick ID from Tractor input
#      brick_objid   Imaging Surveys OBJID on that brick
#             htm9   Ninth level (~10 arcmin resolution) Hierarchical Triangula
#                    r Mesh index (Szalay et al. 2007)
#          ring256   Ring-scheme HEALPix (Gorski et al. 2005) index with Nsides
#                    =256 (~14 arcmin size)
#         nest4096   Nested-scheme HEALPix (Gorski et al. 2005) index with Nsid
#                    es=4096 (~52 arcsec size)
#          release   Imaging Surveys release ID
#           nobs_g   Number of images for central pixel in g-band
#           nobs_r   Number of images for central pixel in r-band
#           nobs_z   Number of images for central pixel in z-band
#        allmask_g   Bitwise mask set if the central pixel from all images sati
#                    sfy each condition in g as cataloged on the LS DR9 bitmask
#                    s page
#        allmask_r   Bitwise mask set if the central pixel from all images sati
#                    sfy each condition in r as cataloged on the LS DR9 bitmask
#                    s page
#        allmask_z   Bitwise mask set if the central pixel from all images sati
#                    sfy each condition in z as cataloged on the LS DR9 bitmask
#                    s page
#      wisemask_w1   W1 bitmask as cataloged on the DR9 bitmasks page here http
#                    s://www.legacysurvey.org/dr9/bitmasks
#      wisemask_w2   W2 bitmask as cataloged on the DR9 bitmasks page here http
#                    s://www.legacysurvey.org/dr9/bitmasks
#         maskbits   Bitwise mask from the imaging indicating potential issue o
#                    r blending
# gaia_astrometric_params_solved   Which astrometric parameters were estimated for a Gaia source
# gaia_duplicated_source   Gaia duplicated source flag
#          ref_cat   Reference catalog source for star: T2 for Tycho2, G2 for G
#                    aia DR2, L2 for the SGA, empty otherwise
#        morphtype   Imaging Surveys morphological type from Tractor
#        brickname   Brick name from Tractor input
#
#
# ==================================================
#
# Schema for table: potential
# --------------------------------------------------
#
# Schema: desi_edr
#  Table: potential
#
#      Column Name   Description
#      -----------   -----------
#               id   Arbitrary primary key composed from targetid, tileid, location
#         targetid   Unique DESI target ID
#        random_id   Random ID in the range 0.0 => 100.0 (not unique)
#           tileid   Unique DESI tile ID
#            fiber   Fiber ID on the CCDs [0-4999]
#         location   Location on the focal plane PETAL_LOC*1000 + DEVICE_LOC
#
#
# ==================================================
#
# Schema for table: have
# --------------------------------------------------
#
# Schema: desi_edr
#  Table: have
#
#      Column Name   Description
#      -----------   -----------
#
#
# ==================================================
#
# Schema for table: target
# --------------------------------------------------
#
# Schema: desi_edr
#  Table: target
#
#      Column Name   Description
#      -----------   -----------
#      subpriority   Random subpriority [0-1] to break assignment ties
#               id   Arbitrary primary key composed from targetid, survey, tileid
#         targetid   Unique DESI target ID
#       cmx_target   Target selection bitmask for commissioning
#      desi_target   Dark survey + calibration targeting bits
#  sv1_desi_target   DESI (dark time program) target selection bitmask for SV1
#   sv1_mws_target   MWS (bright time program) target selection bitmask for SV1
#  sv2_desi_target   DESI (dark time program) target selection bitmask for SV2
#   sv2_mws_target   MWS (bright time program) target selection bitmask for SV2
#  sv3_desi_target   DESI (dark time program) target selection bitmask for SV3
#   sv3_mws_target   MWS (bright time program) target selection bitmask for SV3
#      scnd_target   Target selection bitmask for secondary programs
#  sv1_scnd_target   Secondary target selection bitmask for SV1
#  sv3_scnd_target   Secondary target selection bitmask for SV3
#        random_id   Random ID in the range 0.0 => 100.0 (not unique)
#    priority_init   Target initial priority from target selection bitmasks and
#                    OBSCONDITIONS
#         hpxpixel   HEALPixel containing this location at NSIDE=64 in the NEST
#                    ED scheme
#       bgs_target   BGS (bright time program) target selection bitmask
#   sv1_bgs_target   BGS (bright time program) target selection bitmask for SV1
#   sv3_bgs_target   BGS (bright time program) target selection bitmask for SV3
#           tileid   Unique DESI tile ID
#    obsconditions   Bit-coded of allowed observing conditions
#      numobs_init   Initial number of observations for target calculated acros
#                    s target selection bitmasks and OBSCONDITIONS
#       mws_target   Milky Way Survey targeting bits
#   sv2_bgs_target   BGS (bright time program) target selection bitmask for SV2
#  sv2_scnd_target   Secondary target selection bitmask for SV2
#          photsys   N for the MzLS/BASS photometric system, S for DECaLS
#          program   DESI program type - BRIGHT, DARK, or BACKUP
#           survey   Survey name
#
#
# ==================================================
#
# Schema for table: zed
# --------------------------------------------------
#
# Schema: desi_edr
#  Table: zed
#
#      Column Name   Description
#      -----------   -----------
#
#
# ==================================================
#
# Schema for table: tile
# --------------------------------------------------
#
# Schema: desi_edr
#  Table: tile
#
#      Column Name   Description
#      -----------   -----------
#           survey   Survey name
#          faprgrm   Fiberassign program name
#           tilera   RA of tile given in fiberassign file
#          tiledec   DEC of tile given in fiberassign file
#          exptime   Length of time shutter was open
#      efftime_etc   Effective exposure time for nominal conditions inferred fr
#                    om ETC data
#     efftime_spec   Effective exposure time for nominal conditions derived fro
#                    m the TSNR2 fits to the spectroscopy
#      efftime_gfa   Effective exposure time for nominal conditions derived fro
#                    m exposure GFA data
# lrg_efftime_dark   Effective exposure time for nominal dark conditions inferr
#                    ed for LRG targets
# elg_efftime_dark   Effective exposure time for nominal dark conditions inferr
#                    ed for ELG targets
# bgs_efftime_bright   Effective exposure time for nominal bright conditions infe
#                    rred for BGS targets
# lya_efftime_dark   Effective exposure time for nominal dark conditions inferr
#                    ed for LYA targets
#         mintfrac   Minimum fraction of GOALTIME acceptable for considering a
#                    tile complete
#        random_id   Random ID in the range 0.0 => 100.0 (not unique)
#           tileid   Unique DESI tile ID
#        lastnight   Most recent night with a good exposure
#         goaltime   Goal for total effective exposure time for the tile
#             nexp   Number of exposures used in EFFTIME estimates
#         faflavor   Fiberassign flavor name
#        obsstatus   Observing conditions bitmask
#         goaltype   The intended observing conditions for the tile
#          program   DESI program type - BRIGHT, DARK, or BACKUP
#
#
# ==================================================
#
# Schema for table: x1p5__zpix__allwise__source
# --------------------------------------------------
#
# Schema: desi_edr
#  Table: x1p5__zpix__allwise__source
#
#      Column Name   Description
#      -----------   -----------
#              id1   ID in left/first table (id)
#              ra1   Right ascension in left/first table (mean_fiber_ra)
#             dec1   Declination in left/first table (mean_fiber_dec)
#              id2   ID in right/second table (source_id)
#              ra2   Right ascension in right/second table (ra)
#             dec2   Declination in right/second table (dec)
#         distance   Distance between ra1,dec1 and ra2,dec2 (arcsec)
#
#
# ==================================================
#
# Schema for table: .5
# --------------------------------------------------
#
# Schema: desi_edr
#
#       Table Name   Description
#       ----------   -----------
#         exposure   Summary quantities for every DESI exposure
#      fiberassign   Quantities obtained when a DESI target is assigned to a fiber
#            frame   Summary quantities for each petal of the DESI instrument i
#                    n a given exposure; in normal operation there are ten fram
#                    es for every exposure
#       photometry   Photometric quantities from LS DR9 for every TARGETID
#        potential   For a given tile, this table lists all targets that could
#                    have received a fiber assignment
#           target   The quantities obtained when photometric objects are analy
#                    zed in the target selection process
#             tile   Summary quantities for every DESI tile (pointing on the sky)
# x1p5__zpix__allwise__source   desi_edr.zpix and xmatch_std.allwise__source crossmatch (1
#                    .5 arcsec)
# x1p5__zpix__gaia_dr3__gaia_source   desi_edr.zpix and xmatch_std.gaia_dr3__gaia_source crossma
#                    tch (1.5 arcsec)
# x1p5__zpix__nsc_dr2__object   desi_edr.zpix and xmatch_std.nsc_dr2__object crossmatch (1
#                    .5 arcsec)
# x1p5__zpix__sdss_dr17__specobj   desi_edr.zpix and xmatch_std.sdss_dr17__specobj crossmatch
#                    (1.5 arcsec)
# x1p5__zpix__unwise_dr1__object   desi_edr.zpix and xmatch_std.unwise_dr1__object crossmatch
#                    (1.5 arcsec)
#             zpix   Redshift and other quantities for spectra that have been g
#                    rouped and coadded by HEALPixel
#            ztile   Redshift and other quantities for spectra that have been g
#                    rouped and coadded by tile
#
#
# ==================================================
#
# Schema for table: x1p5__zpix__gaia_dr3__gaia_source
# --------------------------------------------------
#
# Schema: desi_edr
#  Table: x1p5__zpix__gaia_dr3__gaia_source
#
#      Column Name   Description
#      -----------   -----------
#              id1   ID in left/first table (id)
#              ra1   Right ascension in left/first table (mean_fiber_ra)
#             dec1   Declination in left/first table (mean_fiber_dec)
#              id2   ID in right/second table (source_id)
#              ra2   Right ascension in right/second table (ra)
#             dec2   Declination in right/second table (dec)
#         distance   Distance between ra1,dec1 and ra2,dec2 (arcsec)
#
#
# ==================================================
#
# Schema for table: tch
# --------------------------------------------------
#
# Schema: desi_edr
#  Table: tch
#
#      Column Name   Description
#      -----------   -----------
#
#
# ==================================================
#
# Schema for table: x1p5__zpix__nsc_dr2__object
# --------------------------------------------------
#
# Schema: desi_edr
#  Table: x1p5__zpix__nsc_dr2__object
#
#      Column Name   Description
#      -----------   -----------
#              id1   ID in left/first table (id)
#              ra1   Right ascension in left/first table (mean_fiber_ra)
#             dec1   Declination in left/first table (mean_fiber_dec)
#              id2   ID in right/second table (id)
#              ra2   Right ascension in right/second table (ra)
#             dec2   Declination in right/second table (dec)
#         distance   Distance between ra1,dec1 and ra2,dec2 (arcsec)
#
#
# ==================================================
#
# Schema for table: .5
# --------------------------------------------------
#
# Schema: desi_edr
#
#       Table Name   Description
#       ----------   -----------
#         exposure   Summary quantities for every DESI exposure
#      fiberassign   Quantities obtained when a DESI target is assigned to a fiber
#            frame   Summary quantities for each petal of the DESI instrument i
#                    n a given exposure; in normal operation there are ten fram
#                    es for every exposure
#       photometry   Photometric quantities from LS DR9 for every TARGETID
#        potential   For a given tile, this table lists all targets that could
#                    have received a fiber assignment
#           target   The quantities obtained when photometric objects are analy
#                    zed in the target selection process
#             tile   Summary quantities for every DESI tile (pointing on the sky)
# x1p5__zpix__allwise__source   desi_edr.zpix and xmatch_std.allwise__source crossmatch (1
#                    .5 arcsec)
# x1p5__zpix__gaia_dr3__gaia_source   desi_edr.zpix and xmatch_std.gaia_dr3__gaia_source crossma
#                    tch (1.5 arcsec)
# x1p5__zpix__nsc_dr2__object   desi_edr.zpix and xmatch_std.nsc_dr2__object crossmatch (1
#                    .5 arcsec)
# x1p5__zpix__sdss_dr17__specobj   desi_edr.zpix and xmatch_std.sdss_dr17__specobj crossmatch
#                    (1.5 arcsec)
# x1p5__zpix__unwise_dr1__object   desi_edr.zpix and xmatch_std.unwise_dr1__object crossmatch
#                    (1.5 arcsec)
#             zpix   Redshift and other quantities for spectra that have been g
#                    rouped and coadded by HEALPixel
#            ztile   Redshift and other quantities for spectra that have been g
#                    rouped and coadded by tile
#
#
# ==================================================
#
# Schema for table: x1p5__zpix__sdss_dr17__specobj
# --------------------------------------------------
#
# Schema: desi_edr
#  Table: x1p5__zpix__sdss_dr17__specobj
#
#      Column Name   Description
#      -----------   -----------
#              id1   ID in left/first table (id)
#              ra1   Right ascension in left/first table (mean_fiber_ra)
#             dec1   Declination in left/first table (mean_fiber_dec)
#              id2   ID in right/second table (specobjid)
#              ra2   Right ascension in right/second table (ra)
#             dec2   Declination in right/second table (dec)
#         distance   Distance between ra1,dec1 and ra2,dec2 (arcsec)
#
#
# ==================================================
#
# Schema for table: (1.5
# --------------------------------------------------
#
#
#
# ==================================================
#
# Schema for table: x1p5__zpix__unwise_dr1__object
# --------------------------------------------------
#
# Schema: desi_edr
#  Table: x1p5__zpix__unwise_dr1__object
#
#      Column Name   Description
#      -----------   -----------
#              id1   ID in left/first table (id)
#              ra1   Right ascension in left/first table (mean_fiber_ra)
#             dec1   Declination in left/first table (mean_fiber_dec)
#              id2   ID in right/second table (unwise_objid)
#              ra2   Right ascension in right/second table (ra)
#             dec2   Declination in right/second table (dec)
#         distance   Distance between ra1,dec1 and ra2,dec2 (arcsec)
#
#
# ==================================================
#
# Schema for table: (1.5
# --------------------------------------------------
#
#
#
# ==================================================
#
# Schema for table: zpix
# --------------------------------------------------
#
# Schema: desi_edr
#  Table: zpix
#
#      Column Name   Description
#      -----------   -----------
#                z   Redshift measured by Redrock
#             zerr   Redshift error from Redrock
#             chi2   Best fit chi squared
#          coeff_0   Redrock template coefficients
#          coeff_1   Redrock template coefficients
#          coeff_2   Redrock template coefficients
#          coeff_3   Redrock template coefficients
#          coeff_4   Redrock template coefficients
#          coeff_5   Redrock template coefficients
#          coeff_6   Redrock template coefficients
#          coeff_7   Redrock template coefficients
#          coeff_8   Redrock template coefficients
#          coeff_9   Redrock template coefficients
#        deltachi2   Delta-chi-squared for template fit from Redrock
#    mean_fiber_ra   Mean (over exposures) RA of actual fiber position
#   mean_fiber_dec   Mean (over exposures) DEC of actual fiber position
#             elon   Ecliptic longitude
#             elat   Ecliptic latitude
#             glon   Galactic longitude
#             glat   Galactic latitude
#               id   Arbitrary primary key composed from targetid, survey, program
#         targetid   Unique DESI target ID
#    coadd_exptime   Sum of the exposure times contributing to the coadd for th
#                    is target
#     mean_delta_x   Mean (over exposures) fiber difference between measured an
#                    d requested CS5 X location on focal plane
#      rms_delta_x   RMS (over exposures) of the fiber difference between measu
#                    red and requested CS5 X location on focal plane
#     mean_delta_y   Mean (over exposures) fiber difference between measured an
#                    d requested CS5 Y location on focal plane
#      rms_delta_y   RMS (over exposures) of the fiber difference between measu
#                    red and requested CS5 Y location on focal plane
#     std_fiber_ra   Standard deviation (over exposures) of RA of actual fiber
#                    position
#    std_fiber_dec   Standard deviation (over exposures) of DEC of actual fiber
#                    position
# mean_psf_to_fiber_specflux   Mean of the PSF_TO_FIBER_SPECFLUX values of the spectra us
#                    ed in the coadd
#  tsnr2_gpbdark_b   GPBDARK B template (S/N)^2
#      tsnr2_elg_b   ELG B template (S/N)^2
# tsnr2_gpbbright_b   GPBBRIGHT B template (S/N)^2
#      tsnr2_lya_b   LYA B template (S/N)^2
#      tsnr2_bgs_b   BGS B template (S/N)^2
# tsnr2_gpbbackup_b   GPBBACKUP B template (S/N)^2
#      tsnr2_qso_b   QSO B template (S/N)^2
#      tsnr2_lrg_b   LRG B template (S/N)^2
#  tsnr2_gpbdark_r   GPBDARK R template (S/N)^2
#      tsnr2_elg_r   ELG R template (S/N)^2
# tsnr2_gpbbright_r   GPBBRIGHT R template (S/N)^2
#      tsnr2_lya_r   LYA R template (S/N)^2
#      tsnr2_bgs_r   BGS R template (S/N)^2
# tsnr2_gpbbackup_r   GPBBACKUP R template (S/N)^2
#      tsnr2_qso_r   QSO R template (S/N)^2
#      tsnr2_lrg_r   LRG R template (S/N)^2
#  tsnr2_gpbdark_z   GPBDARK Z template (S/N)^2
#      tsnr2_elg_z   ELG Z template (S/N)^2
# tsnr2_gpbbright_z   GPBBRIGHT Z template (S/N)^2
#      tsnr2_lya_z   LYA Z template (S/N)^2
#      tsnr2_bgs_z   BGS Z template (S/N)^2
# tsnr2_gpbbackup_z   GPBBACKUP Z template (S/N)^2
#      tsnr2_qso_z   QSO Z template (S/N)^2
#      tsnr2_lrg_z   LRG Z template (S/N)^2
#    tsnr2_gpbdark   GPBDARK template (S/N)^2 summed over B, R, Z
#        tsnr2_elg   ELG template (S/N)^2 summed over B, R, Z
#  tsnr2_gpbbright   GPBBRIGHT template (S/N)^2 summed over B, R, Z
#        tsnr2_lya   LYA template (S/N)^2 summed over B, R, Z
#        tsnr2_bgs   BGS template (S/N)^2 summed over B, R, Z
#  tsnr2_gpbbackup   GPBBACKUP template (S/N)^2 summed over B, R, Z
#        tsnr2_qso   QSO template (S/N)^2 summed over B, R, Z
#        tsnr2_lrg   LRG template (S/N)^2 summed over B, R, Z
#        random_id   Random ID in the range 0.0 => 100.0 (not unique)
#         spgrpval   Value corresponding to the grouping type indicated in the
#                    spgrp column. For zpix table this is the same as the healp
#                    ix column
#          healpix   HEALPixel containing this location at NSIDE=64 in the NEST
#                    ED scheme
# coadd_fiberstatus   Bitwise AND of the FIBERSTATUS values of the spectra used
#                    in the coadd
#             htm9   Ninth level (~10 arcmin resolution) Hierarchical Triangula
#                    r Mesh index (Szalay et al. 2007)
#          ring256   Ring-scheme HEALPix (Gorski et al. 2005) index with Nsides
#                    =256 (~14 arcmin size)
#         nest4096   Nested-scheme HEALPix (Gorski et al. 2005) index with Nsid
#                    es=4096 (~52 arcsec size)
#            zwarn   Redshift warning bitmask measured by Redrock
#          npixels   Number of unmasked wavelengths that contributed to the red
#                    shift fit
#           ncoeff   Number of Redrock template coefficients
#     coadd_numexp   Number of exposures included in the coadd for this target
#   coadd_numnight   Number of different nights included in the coadd for this
#                    target
#    coadd_numtile   Number of different tiles included in the coadd for this target
#         sv_nspec   Number of coadded spectra for this TARGETID in SV (SV1+2+3)
#       main_nspec   Number of coadded spectra for this TARGETID in Main survey
#       zcat_nspec   Number of coadded spectra for this TARGETID in this zcatalog
#       sv_primary   Boolean flag (True/False) for the primary coadded spectrum
#                    in SV (SV1+2+3)
#     main_primary   Boolean flag (True/False) for the primary coadded spectrum
#                    in Main survey
#     zcat_primary   Boolean flag (True/False) for the primary coadded spectrum
#                    in this zcatalog
#            spgrp   Type of spectral grouping. For zpix table this is always =
#                    healpix
#          subtype   Spectral subtype
#          program   DESI program type - BRIGHT, DARK, or BACKUP
#         spectype   Spectype from Redrock file
#           survey   Survey name
#       firstnight   KPNO Calendar Date for the first NIGHT of observation coad
#                    ded into the spectrum
#        lastnight   KPNO Calendar Date for the last NIGHT of the last observat
#                    ion coadded into the spectrum
#         mean_mjd   Mean (over exposures) of the Modified Julian Date (MJD) wh
#                    en the shutter was opened
#          min_mjd   Minimum value of the Modified Julian Date (when the shutte
#                    r was open for the first exposure)
#          max_mjd   Maximum value of the Modified Julian Date (when the shutte
#                    r was open for the last exposure, i.e. not including the e
#                    xposure time)
#       mws_target   Milky Way Survey targeting bits
#   sv1_mws_target   MWS (bright time program) target selection bitmask for SV1
#   sv2_mws_target   MWS (bright time program) target selection bitmask for SV2
#   sv3_mws_target   MWS (bright time program) target selection bitmask for SV3
#      scnd_target   Target selection bitmask for secondary programs
#  sv1_scnd_target   Secondary target selection bitmask for SV1
#  sv2_scnd_target   Secondary target selection bitmask for SV2
#  sv3_scnd_target   Secondary target selection bitmask for SV3
#       bgs_target   BGS (bright time program) target selection bitmask
#   sv1_bgs_target   BGS (bright time program) target selection bitmask for SV1
#   sv2_bgs_target   BGS (bright time program) target selection bitmask for SV2
#   sv3_bgs_target   BGS (bright time program) target selection bitmask for SV3
#      desi_target   Dark survey + calibration targeting bits
#  sv1_desi_target   DESI (dark time program) target selection bitmask for SV1
#  sv2_desi_target   DESI (dark time program) target selection bitmask for SV2
#  sv3_desi_target   DESI (dark time program) target selection bitmask for SV3
#       cmx_target   Target selection bitmask for commissioning
#
#
# ==================================================
#
# Schema for table: rouped
# --------------------------------------------------
#
# Schema: desi_edr
#  Table: rouped
#
#      Column Name   Description
#      -----------   -----------
#
#
# ==================================================
#
# Schema for table: ztile
# --------------------------------------------------
#
# Schema: desi_edr
#  Table: ztile
#
#      Column Name   Description
#      -----------   -----------
#                z   Redshift measured by Redrock
#             zerr   Redshift error from Redrock
#             chi2   Best fit chi squared
#          coeff_0   Redrock template coefficients
#          coeff_1   Redrock template coefficients
#          coeff_2   Redrock template coefficients
#          coeff_3   Redrock template coefficients
#          coeff_4   Redrock template coefficients
#          coeff_5   Redrock template coefficients
#          coeff_6   Redrock template coefficients
#          coeff_7   Redrock template coefficients
#          coeff_8   Redrock template coefficients
#          coeff_9   Redrock template coefficients
#        deltachi2   Delta-chi-squared for template fit from Redrock
#    mean_fiber_ra   Mean (over exposures) RA of actual fiber position
#   mean_fiber_dec   Mean (over exposures) DEC of actual fiber position
#             elon   Ecliptic longitude
#             elat   Ecliptic latitude
#             glon   Galactic longitude
#             glat   Galactic latitude
#               id   Arbitrary primary key composed from targetid, survey, program
#     targetphotid   Foreign key on the target table
#         targetid   Unique DESI target ID
#    coadd_exptime   Sum of the exposure times contributing to the coadd for th
#                    is target
#     mean_delta_x   Mean (over exposures) fiber difference between measured an
#                    d requested CS5 X location on focal plane
#      rms_delta_x   RMS (over exposures) of the fiber difference between measu
#                    red and requested CS5 X location on focal plane
#     mean_delta_y   Mean (over exposures) fiber difference between measured an
#                    d requested CS5 Y location on focal plane
#      rms_delta_y   RMS (over exposures) of the fiber difference between measu
#                    red and requested CS5 Y location on focal plane
#     std_fiber_ra   Standard deviation (over exposures) of RA of actual fiber
#                    position
#    std_fiber_dec   Standard deviation (over exposures) of DEC of actual fiber
#                    position
# mean_psf_to_fiber_specflux   Mean of the PSF_TO_FIBER_SPECFLUX values of the spectra us
#                    ed in the coadd
#  tsnr2_gpbdark_b   GPBDARK B template (S/N)^2
#      tsnr2_elg_b   ELG B template (S/N)^2
# tsnr2_gpbbright_b   GPBBRIGHT B template (S/N)^2
#      tsnr2_lya_b   LYA B template (S/N)^2
#      tsnr2_bgs_b   BGS B template (S/N)^2
# tsnr2_gpbbackup_b   GPBBACKUP B template (S/N)^2
#      tsnr2_qso_b   QSO B template (S/N)^2
#      tsnr2_lrg_b   LRG B template (S/N)^2
#  tsnr2_gpbdark_r   GPBDARK R template (S/N)^2
#      tsnr2_elg_r   ELG R template (S/N)^2
# tsnr2_gpbbright_r   GPBBRIGHT R template (S/N)^2
#      tsnr2_lya_r   LYA R template (S/N)^2
#      tsnr2_bgs_r   BGS R template (S/N)^2
# tsnr2_gpbbackup_r   GPBBACKUP R template (S/N)^2
#      tsnr2_qso_r   QSO R template (S/N)^2
#      tsnr2_lrg_r   LRG R template (S/N)^2
#  tsnr2_gpbdark_z   GPBDARK Z template (S/N)^2
#      tsnr2_elg_z   ELG Z template (S/N)^2
# tsnr2_gpbbright_z   GPBBRIGHT Z template (S/N)^2
#      tsnr2_lya_z   LYA Z template (S/N)^2
#      tsnr2_bgs_z   BGS Z template (S/N)^2
# tsnr2_gpbbackup_z   GPBBACKUP Z template (S/N)^2
#      tsnr2_qso_z   QSO Z template (S/N)^2
#      tsnr2_lrg_z   LRG Z template (S/N)^2
#    tsnr2_gpbdark   GPBDARK template (S/N)^2 summed over B, R, Z
#        tsnr2_elg   ELG template (S/N)^2 summed over B, R, Z
#  tsnr2_gpbbright   GPBBRIGHT template (S/N)^2 summed over B, R, Z
#        tsnr2_lya   LYA template (S/N)^2 summed over B, R, Z
#        tsnr2_bgs   BGS template (S/N)^2 summed over B, R, Z
#  tsnr2_gpbbackup   GPBBACKUP template (S/N)^2 summed over B, R, Z
#        tsnr2_qso   QSO template (S/N)^2 summed over B, R, Z
#        tsnr2_lrg   LRG template (S/N)^2 summed over B, R, Z
#        random_id   Random ID in the range 0.0 => 100.0 (not unique)
#             htm9   Ninth level (~10 arcmin resolution) Hierarchical Triangula
#                    r Mesh index (Szalay et al. 2007)
#          ring256   Ring-scheme HEALPix (Gorski et al. 2005) index with Nsides
#                    =256 (~14 arcmin size)
#         nest4096   Nested-scheme HEALPix (Gorski et al. 2005) index with Nsid
#                    es=4096 (~52 arcsec size)
#         spgrpval   Value corresponding to the grouping type indicated in the
#                    spgrp column. For ztile table this is a night or exposure
#                    id
# coadd_fiberstatus   Bitwise AND of the FIBERSTATUS values of the spectra used
#                    in the coadd
#           tileid   Unique DESI tile ID
#            zwarn   Redshift warning bitmask measured by Redrock
#          npixels   Number of unmasked wavelengths that contributed to the red
#                    shift fit
#           ncoeff   Number of Redrock template coefficients
#     coadd_numexp   Number of exposures included in the coadd for this target
#   coadd_numnight   Number of different nights included in the coadd for this
#                    target
#    coadd_numtile   Number of different tiles included in the coadd for this target
#         sv_nspec   Number of coadded spectra for this TARGETID in SV (SV1+2+3)
#       main_nspec   Number of coadded spectra for this TARGETID in Main survey
#       zcat_nspec   Number of coadded spectra for this TARGETID in this zcatalog
#       sv_primary   Boolean flag (True/False) for the primary coadded spectrum
#                    in SV (SV1+2+3)
#     main_primary   Boolean flag (True/False) for the primary coadded spectrum
#                    in Main survey
#     zcat_primary   Boolean flag (True/False) for the primary coadded spectrum
#                    in this zcatalog
#            spgrp   Type of spectral grouping. For ztile table this can be = c
#                    umulative, perexp, or pernight
#          subtype   Spectral subtype
#          program   DESI program type - BRIGHT, DARK, or BACKUP
#         spectype   Spectype from Redrock file
#           survey   Survey name
#        lastnight   KPNO Calendar Date for the last NIGHT of the observation o
#                    f the TILEID
#       firstnight   KPNO Calendar Date for the first NIGHT of the observation
#                    of the TILEID
#         mean_mjd   Mean (over exposures) of the Modified Julian Date (MJD) wh
#                    en the shutter was opened
#          max_mjd   Maximum value of the Modified Julian Date (when the shutte
#                    r was open for the last exposure, i.e. not including the e
#                    xposure time)
#          min_mjd   Minimum value of the Modified Julian Date (when the shutte
#                    r was open for the first exposure)
#     mean_fiber_x   Mean (over exposures) fiber CS5 X location on focal plane
#     mean_fiber_y   Mean (over exposures) fiber CS5 Y location on focal plane
#
#
# ==================================================
#
# Schema for table: rouped
# --------------------------------------------------
#
# Schema: desi_edr
#  Table: rouped
#
#      Column Name   Description
#      -----------   -----------
#
#
# ==================================================

# %%
print(qc.schema('smash_dr1'))
# Out:
# Schema: smash_dr1
#
#       Table Name   Description
#       ----------   -----------
#             chip   Info on each chip in the frame
#         exposure   Info on each exposure
#            field   Info on each target field (position, Num exposures, etc)
#         galaxies   View of object table to select for galaxies
#           object   Average photometry of each unique object
#           source   All of the individual source measurements
#            stars   View of object table to select for stars
# x1p5__object__gaia_dr3__gaia_source   smash_dr1.object and gaia_dr3.gaia_source crossmatch (1.5
#                    arcsec)
# x1p5__object__nsc_dr2__object   smash_dr1.object and nsc_dr2.object crossmatch (1.5 arcsec)
# x1p5__object__unwise_dr1__object   smash_dr1.object and unwise_dr1.object crossmatch (1.5 arcsec)
#           xmatch   Crossmatch of object against GAIA DR1 and WISE

# %% [markdown]
# ### Get list of columns
# We can also use `qc.schema()` to get column names and descriptions for a specific table.  Here's what's available for the SMASH DR1 object table.  (Note that not all datasets have column descriptions for every column).

# %%
print(qc.schema('smash_dr1.object'))
# Out:
# Schema: smash_dr1
#  Table: object
#
#      Column Name   Description
#      -----------   -----------
#               id   Unique ID for this object, the field name plus a running number
#          fieldid   SMASH Field ID
#               ra   Right Ascension (J2000.0) of source, in degrees
#              dec   Declination (J2000.0) of source, in degrees
#             glon   Galactic Longitude
#             glat   Galactic Latitude
#             elon   Ecliptic Longitude
#             elat   Ecliptic Latitude
#             htm9   HTM index (order 9 => ~10 arcmin size)
#          ring256   HEALPIX index (Nsides 256, Ring scheme => ~14 arcmin size)
#         nest4096   HEALPIX index (Nsides 4096, Nest scheme => ~52 arcsec size
#        random_id   Random ID in the range 0.0 => 100.0
#            raerr   Uncertainty in mean RA of object (arcseconds) from indiv values
#           decerr   Uncertainty in mean DEC of object (arcseconds) from indiv
#                    values
#             ndet   Number of detections of this source (in ALLSRC)
#        depthflag   Flag of exposure detected in: 1-shallow, 2-deep, 3-both
#             umag   Weighted-average, calibrated u-band magnitude, 99.99 if no
#                    detection
#             uerr   Uncertainty in calibrated u-band magnitude
#         uscatter   RMS scatter in u from multiple measurements of this object
#            ndetu   Number of detections in u
#             gmag   Weighted-average, calibrated g-band magnitude, 99.99 if no
#                    detection
#             gerr   Unceratinty in calibrated g-band magnitude
#         gscatter   RMS scatter in g from multiple measurements of this object
#            ndetg   Number of detections in g
#             rmag   Weighted-avarage, calibrated r-band magnitude, 99.99 if no
#                    detection
#             rerr   Uncertainty in calibrated r-band magnitude
#         rscatter   RMS scatter in r from multiple measurements of this object
#            ndetr   Number of detections in r
#             imag   Weighted-average, calibrated i-band magnitude, 99.99 if no
#                    detection
#             ierr   Uncertainty in calibrated i-band magnitude
#         iscatter   RMS scatter in i from multiple measurements of this object
#            ndeti   Number of detections in i
#             zmag   Weighted-avarege, calibrated z-band magnitude, 99.99 if no
#                    detection
#             zerr   Uncertainty in calibrated z-band magnitude
#         zscatter   RMS scatter in z from multiple measurements of this object
#            ndetz   Number of detections in z
#              u_g   u-g color index
#              g_r   g-r color index
#              g_i   g-i color index
#              i_z   i-z color index
#              chi   Average DAOPHOT chi value, i.e. how well the PSF fit this
#                    source
#            sharp   Average DAOPHOT sharp value, measurement of peakiness
#             flag   OR-combined Source Extractor FLAG value from coadd image
#             prob   Average Source Extractor stellaricity probability value
#              ebv   Median SFD E(B-V) across frame

# %% [markdown]
# ### Getting statistics for tables
# You'll often want to get some basic information about a given table, e.g. the number of rows.  One might be tempted to use `SELECT COUNT(*)` in a query for this -- but that can be slow on large datasets, and is often not needed. Instead, the special database `tbl_stat` contains this information for each dataset. Let's query this table instead:

# %%
query = "SELECT * FROM tbl_stat WHERE schema='ztile' AND tbl_name='spectype'"
info = qc.query(sql=query) # by default the result is a CSV formatted string
print(info)
print(type(info))
print(info[:1000]) # print just the first 1000 characters of the returned string
df = convert(info,'pandas')
df.head()
# Out:
# schema,tbl_name,nrows,ncols,nindex,table_size,indexes_size,total_size
#
# <class 'str'>
# schema,tbl_name,nrows,ncols,nindex,table_size,indexes_size,total_size
# Empty DataFrame
# Columns: [schema, tbl_name, nrows, ncols, nindex, table_size, indexes_size, total_size]
# Index: []

# %%
#query = "SELECT COUNT(ra) FROM phat_v2.phot_mod" # SLOW
query = "SELECT * FROM tbl_stat WHERE schema='smash_dr1' AND tbl_name='object'" # Retrieve useful stats, quickly

# %%
info = qc.query(sql=query) # by default the result is a CSV formatted string

# %%
print(info)
# Out:
# schema,tbl_name,nrows,ncols,nindex,table_size,indexes_size,total_size
# smash_dr1,object,101425176,45,31,23745896448,49695866880,73441763328

# %% [markdown]
# <a class="anchor" id="query"></a>
# # A simple query for catalog data
# In the above section we already saw a basic query of the `tbl_stats` database. Here we will retrieve the first 10 rows from the `smash_dr1.object` table:

# %%
query = "SELECT * FROM smash_dr1.object LIMIT 10"
result = qc.query(sql=query) # by default the result is a CSV formatted string

# %% [markdown]
# Note that by default the result is returned as a long string that looks like a CSV file:

# %%
print(type(result))
print(result[:1000]) # print just the first 1000 characters of the returned string
# Out:
# <class 'str'>
# ra,dec,glon,glat,elon,elat,htm9,ring256,nest4096,random_id,raerr,decerr,umag,uerr,uscatter,gmag,gerr,gscatter,rmag,rerr,rscatter,imag,ierr,iscatter,zmag,zerr,zscatter,u_g,g_r,g_i,i_z,chi,sharp,prob,ebv,ndet,depthflag,ndetu,ndetg,ndetr,ndeti,ndetz,flag,fieldid,id
# 129.65202789947685,-73.34941050705731,287.2584936987078,-18.77875814515035,224.34171283213647,-75.18727575171535,2479149,769819,151931040,88.73219,0.19425105,0.19425105,24.905962,0.42259353,0.1068422,99.99,9.99,99.99,99.99,9.99,99.99,22.507595,0.29619363,99.99,23.022808,0.2669347,99.99,0,0,0,-0.515213,0.84,1.813,0.73599994,0.15548147,5,2,3,0,0,1,1,0,66,66.1365204
# 129.65169260445919,-73.34935625833235,287.25839042007203,-18.77880925254502,224.34154703576704,-75.18737761627118,2479149,769819,151931040,17.864498,0.036660124,0.036660124,99.99,9.99,99.99,24.03043,0.08351327,0.08328069,23.320858,0.057600196,0.30165642,22.942156,0.052102964,0.25821632,23.068672,0.096364394,0.15875103,0,0.70957184,1.088274,-0.12651634,0.86672723,1.2251

# %% [markdown]
# We would generally want to convert this string into a table or an array, i.e., into some format that allows numerical processing.  The Data Lab `helpers` module makes it easy. Here we convert the result string result into a Pandas dataframe:

# %%
df = convert(result,'pandas')
df.head()
# Out:
#            ra        dec        glon       glat        elon       elat  \
# 0  129.652028 -73.349411  287.258494 -18.778758  224.341713 -75.187276
# 1  129.651693 -73.349356  287.258390 -18.778809  224.341547 -75.187378
# 2  129.652160 -73.349178  287.258310 -18.778600  224.340794 -75.187266
# 3  129.650847 -73.349304  287.258205 -18.778984  224.341458 -75.187624
# 4  129.650951 -73.349486  287.258384 -18.779058  224.342152 -75.187573
#
#       htm9  ring256   nest4096  random_id  ...  ndet  depthflag  ndetu  ndetg  \
# 0  2479149   769819  151931040  88.732190  ...     5          2      3      0
# 1  2479149   769819  151931040  17.864498  ...    22          3      0      3
# 2  2479149   769819  151931040  13.545553  ...     6          2      0      0
# 3  2479149   769819  151931040  43.160904  ...     2          1      0      1
# 4  2479149   769819  151931040  13.559463  ...    21          2      3      3
#
#    ndetr  ndeti  ndetz  flag  fieldid         id
# 0      0      1      1     0       66  66.136520
# 1      7      7      5     2       66  66.391596
# 2      2      3      1     2       66  66.391176
# 3      1      0      0    -1       66  66.144068
# 4      4      5      6     2       66  66.391552
#
# [5 rows x 45 columns]

# %% [markdown]
# Note that for convenience one can request the result to be in a number of other formats, including a Pandas DataFrame:

# %%
query = "SELECT * FROM smash_dr1.object LIMIT 10"
df = qc.query(sql=query,fmt='pandas')
df.head()
# Out:
#            ra        dec        glon       glat        elon       elat  \
# 0  129.652028 -73.349411  287.258494 -18.778758  224.341713 -75.187276
# 1  129.651693 -73.349356  287.258390 -18.778809  224.341547 -75.187378
# 2  129.652160 -73.349178  287.258310 -18.778600  224.340794 -75.187266
# 3  129.650847 -73.349304  287.258205 -18.778984  224.341458 -75.187624
# 4  129.650951 -73.349486  287.258384 -18.779058  224.342152 -75.187573
#
#       htm9  ring256   nest4096  random_id  ...  ndet  depthflag  ndetu  ndetg  \
# 0  2479149   769819  151931040  88.732190  ...     5          2      3      0
# 1  2479149   769819  151931040  17.864498  ...    22          3      0      3
# 2  2479149   769819  151931040  13.545553  ...     6          2      0      0
# 3  2479149   769819  151931040  43.160904  ...     2          1      0      1
# 4  2479149   769819  151931040  13.559463  ...    21          2      3      3
#
#    ndetr  ndeti  ndetz  flag  fieldid         id
# 0      0      1      1     0       66  66.136520
# 1      7      7      5     2       66  66.391596
# 2      2      3      1     2       66  66.391176
# 3      1      0      0    -1       66  66.144068
# 4      4      5      6     2       66  66.391552
#
# [5 rows x 45 columns]

# %% [markdown]
# The results of a query like this can be stored to your VOSpace (remote user file storage) or to MyDB (remote user database), if you logged in as an authenticated user. See some of the Data Lab [How-To notebooks](https://github.com/astro-datalab/notebooks-latest/tree/058d6a71dbdd7f4f19a38f5ec6f78cd9b107113c/04_HowTos) for for examples of this.

# %% [markdown]
# <a class="anchor" id="image"></a>
# # Find and download an image cutout
# Using the image cutout service is a two-step process. First, we specify a position (RA and Dec), and the size of the image that we want to retrieve. Second, we then search the SIA service for all images that overlap that point on the sky:

# %%
# NGC 288 (a globular cluster)
ra = 13.19     # in decimal degrees
dec = -26.59   # in decimal degrees

fov = 13/60  # image cutout field of view (in degrees; here 13 arminutes = 0.22 degrees)

imgTable = svc.search((ra,dec), (fov/np.cos(dec*np.pi/180), fov), verbosity=2).to_table()  # uses declination correction

# %% [markdown]
# The result is a VOTable that we convert to an astropy Table on the fly. The table contains many columns of metadata describing the parameters of each image, including a URL for the cutout itself. Note, however, that data quality images such as masks or weight maps can also appear in the list:

# %%
print(type(imgTable))
imgTable
# Out:
# <class 'astropy.table.table.Table'>
# <Table length=18>
# assoc_id ... elliptic
#          ...
#  object  ...  object
# -------- ... --------
#  des_dr1 ...        0
#  des_dr1 ...        0
#  des_dr1 ...        0
#  des_dr1 ...        0
#  des_dr1 ...        0
#  des_dr1 ...        0
#  des_dr1 ...        0
#  des_dr1 ...        0
#  des_dr1 ...        0
#  des_dr1 ...        0
#  des_dr1 ...        0
#  des_dr1 ...        0
#  des_dr1 ...        0
#  des_dr1 ...        0
#  des_dr1 ...        0
#  des_dr1 ...        0
#  des_dr1 ...        0
#  des_dr1 ...        0

# %% [markdown]
# The next step is to identify the image that you want from the list of available images.  Here we will limit the list to g-band image stacks, and select the `image` product type (rather than weights or masks).

# %%
# boolean selection for just g-band images
sel0 = imgTable['obs_bandpass'] == 'g'

# logically add selections for 'Stack' and 'image' product type
sel = sel0 & ((imgTable['proctype'] == 'Stack') & (imgTable['prodtype'] == 'image')) # basic selection

# filter the above results table
Table = imgTable[sel] # select
Table
# Out:
# <Table length=1>
# assoc_id ... elliptic
#          ...
#  object  ...  object
# -------- ... --------
#  des_dr1 ...        0

# %% [markdown]
# The final step is to extract the URL and download the image:

# %%
row = Table[0]
url = row['access_url'] # get the download URL
print(url)
# Out:
# https://datalab.noirlab.edu/svc/cutout?col=des_dr1&siaRef=DES0052-2623_r2628p04_g.fits.fz&extn=1&POS=13.19,-26.59&SIZE=0.2422934725574616,0.21666666666666667

# %%
gimage = io.fits.getdata(utils.data.download_file(url,cache=True,show_progress=False,timeout=120))

# %% [markdown]
# We'll do a quick display here:

# %%
fig = plt.subplots(figsize=(10,10))
plt.imshow(np.arcsinh(gimage),cmap='gray',norm=matplotlib.colors.Normalize(vmin=0))
plt.axis('off');

# %% [markdown]
# ## Let's make a color image
# Let's write a quick function to do the SIA query and image selection for us:

# %%
# A function to download the deepest available stacked images
def download_deep_stack(ra,dec,fov=0.1,band='g'):
    imgTable = svc.search((ra,dec), (fov/np.cos(dec*np.pi/180), fov), verbosity=2).to_table()
    print("The full image list contains", len(imgTable), "entries")

    # apply image seletion criteria
    sel0 = imgTable['obs_bandpass'] == band
    sel = sel0 & ((imgTable['proctype'] == 'Stack') & (imgTable['prodtype'] == 'image')) # basic selection
    Table = imgTable[sel] # select

    # if more than one image matches our desired criteria
    if (len(Table)>0):
        row = Table[np.argmax(Table['exptime'].data.data.astype('float'))] # pick image with longest exposure time
        url = row['access_url'] # get the download URL
        print ('Downloading deepest stacked image...')
        image = io.fits.getdata(utils.data.download_file(url,cache=True,show_progress=False,timeout=120))
        print(url)

    # if no images match our criteria
    else:
        print ('No image available.')
        image = None
        
    print()
    return image

# %% [markdown]
# Using this function we can now quickly download two more bands (r and i bands), and combine them with the g-band image to make a false-color image:

# %%
rimage = download_deep_stack(ra,dec,fov,band='r')
iimage = download_deep_stack(ra,dec,fov,band='i')
# Out:
# The full image list contains 18 entries
# Downloading deepest stacked image...
# https://datalab.noirlab.edu/svc/cutout?col=des_dr1&siaRef=DES0052-2623_r2628p04_r.fits.fz&extn=1&POS=13.19,-26.59&SIZE=0.2422934725574616,0.21666666666666667
#
# The full image list contains 18 entries
# Downloading deepest stacked image...
# https://datalab.noirlab.edu/svc/cutout?col=des_dr1&siaRef=DES0052-2623_r2628p04_i.fits.fz&extn=1&POS=13.19,-26.59&SIZE=0.2422934725574616,0.21666666666666667

# %% [markdown]
# Now we can do the combination of images in three bands:

# %%
color_image = make_lupton_rgb(iimage, rimage, gimage, stretch=100, Q=0.1)

# %% [markdown]
# And plot the resulting false-color image:

# %%
fig = plt.figure(figsize=(10,10))
plt.imshow(color_image)
plt.axis('off');

# %% [markdown]
# <a class="anchor" id="resources"></a>
# # Further resources and references
# * This notebook is [available on GitHub](https://github.com/astro-datalab/notebooks-latest/blob/058d6a71dbdd7f4f19a38f5ec6f78cd9b107113c/01_GettingStartedWithDataLab/02_GettingStartedWithDataLab.ipynb)
# * An in-depth [notebook on Simple Image Access](https://github.com/astro-datalab/notebooks-latest/blob/058d6a71dbdd7f4f19a38f5ec6f78cd9b107113c/04_HowTos/SiaService/How_to_use_the_Simple_Image_Access_service.ipynb)
# * Info about the [globular cluster NGC 288](https://en.wikipedia.org/wiki/NGC_288)
